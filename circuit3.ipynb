# %%
from qiskit import *
from qiskit.quantum_info import Operator

# %%
circuit = QuantumCircuit(3,3)

# %%
# %matplotlib inline
circuit.draw(initial_state=True)
# Out:
#
# q_0: |0>
#
# q_1: |0>
#
# q_2: |0>
#
#  c: 0 3/

# %%
circuit.draw(output='mpl')

# %%
circuit.x(0)
circuit.barrier()
circuit.draw('mpl')

# %%
circuit.h(1)
circuit.cx(1,2)
circuit.draw('mpl')

# %%
circuit.cx(0,1)
circuit.h(0)
circuit.draw('mpl')

# %%
circuit.barrier()
circuit.measure([0,1] , [0,1])
circuit.draw('mpl')

# %%
circuit.barrier()
circuit.cx(1,2)
circuit.cz(0,2)
circuit.draw('mpl')

# %%
circuit.measure(2,2)
simulator = Aer.get_backend('qasm_simulator')
result = execute(circuit,backend=simulator,shots=1024).result()
counts = result.get_counts()
from qiskit.tools.visualization import plot_histogram
plot_histogram(counts)

# %%
print(counts)
# Out:
# {'110': 273, '111': 258, '101': 244, '100': 249}

# %%
U = Operator(circuit)
print(U.data)
# Out:
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# f:\Qiskit\circuit3.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/f%3A/Qiskit/circuit3.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> U = Operator(circuit)
#       <a href='vscode-notebook-cell:/f%3A/Qiskit/circuit3.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> print(U.data)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\qiskit\quantum_info\operators\operator.py:97, in Operator.__init__(self, data, input_dims, output_dims)
#      88     self._data = np.asarray(data, dtype=complex)
#      89 elif isinstance(data, (QuantumCircuit, Operation)):
#      90     # If the input is a Terra QuantumCircuit or Operation we
#      91     # perform a simulation to construct the unitary operator.
#    (...)
#      95     # conditional gates, measure, or reset will cause an
#      96     # exception to be raised.
# ---> 97     self._data = self._init_instruction(data).data
#      98 elif hasattr(data, "to_operator"):
#      99     # If the data object has a 'to_operator' attribute this is given
#     100     # higher preference than the 'to_matrix' method for initializing
#     101     # an Operator object.
#     102     data = data.to_operator()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\qiskit\quantum_info\operators\operator.py:632, in Operator._init_instruction(cls, instruction)
#     630 if isinstance(instruction, QuantumCircuit):
#     631     instruction = instruction.to_instruction()
# --> 632 op._append_instruction(instruction)
#     633 return op
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\qiskit\quantum_info\operators\operator.py:700, in Operator._append_instruction(self, obj, qargs)
#     698 for instruction in flat_instr:
#     699     if instruction.clbits:
# --> 700         raise QiskitError(
#     701             "Cannot apply operation with classical bits:"
#     702             f" {instruction.operation.name}"
#     703         )
#     704     # Get the integer position of the flat register
#     705     if qargs is None:
#
# QiskitError: 'Cannot apply operation with classical bits: measure'
